# %%
# %load_ext autoreload
# %autoreload 2

from mdp_dp_rl.algorithms.dp.dp_analytic import DPAnalytic

from stochastic_service_composition.declare_utils import *
from stochastic_service_composition.composition_mdp import composition_mdp
from stochastic_service_composition.composition_mdp import comp_mdp
from stochastic_service_composition.dfa_target import mdp_from_dfa

from src.motor.utils import *
import src.motor.setup as setup

# %% [markdown]
# ## Services properties

# %%
all_services = setup.process_services("xsmall")

# %% [markdown]
# ## LTLf debug

# %%
declare_automaton = setup.target_service_ltlf()
render_mdp_dfa(mdp_from_dfa(declare_automaton), no_sink=True)

# %%
mdp = comp_mdp(declare_automaton, all_services, gamma=0.9)
render_comp_mdp(mdp)

# %%
opn = DPAnalytic(mdp, 1e-4)
opt_policy = opn.get_optimal_policy_vi()
opt_policy.policy_data.pop(0, None)
print_policy_data(opt_policy)
# Out:
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 0),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 4),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 3),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 2),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 7),	Action={('ret_s', 2): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 6),	Action={('ret_r', 1): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 5),	Action={('ret_i', 0): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 8),	Action={('con_ass', 3): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 8),	Action={('res_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'av', 're', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'br', 're', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'br', 're', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'av', 'br', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'av', 'br', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'av', 're', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'br', 'br', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'br', 're', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'br', 'br', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'av', 'br', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'av', 'br', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'br', 'br', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'br', 'br', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'av', 'br', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'av', 're', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'av', 're', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'br', 're', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'av', 'br', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'br', 're', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'av', 're', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'br', 'br', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'av', 'br', 'br', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'av', 'br', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'av', 'br', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'av', 're', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'br', 're', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'av', 're', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'br', 'br', 'br', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'br', 're', 'br'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'br', 're', 'av'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'con', 'br', 'br', 'br', 'av'), 8),	Action={('che_ass', 3): 1.0}
# State=(('re', 're', 're', 'rep', 'av', 'av', 're', 'br'), 8),	Action={('rep_ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'av', 're', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'br', 're', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'av', 'br', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'av', 'br', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'br', 'br', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'av', 'br', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'br', 'br', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'av', 're', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'av', 're', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'br', 're', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'av', 'br', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'br', 're', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'br', 'br', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'av', 're', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'br', 're', 'br'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 'ex', 'br', 'br', 'br', 'av'), 8),	Action={('ass', 3): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 9),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 9),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 9),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 9),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 9),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 9),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 9),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 9),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 9),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 're', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 're', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'con', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 're', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 're', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'con', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 're', 'av'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'con', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 're', 'av'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'con', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'br', 'av'), 12),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 12),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'rep', 'av'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'do'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'av'), 12),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 12),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'rep', 'av'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'do'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 'br', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 'br', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'rep', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'br', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'br', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'rep', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'br', 'br'), 11),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 11),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'rep', 'br'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'br', 'br'), 11),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 11),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'rep', 'br'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'br', 'br'), 12),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 12),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'rep', 'br'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'br'), 12),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 12),	Action={('res_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'rep', 'br'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'rep', 'br'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'br'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 're', 'av'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'con', 'av'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'do'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 're', 'av'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'con', 'av'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'do'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 're', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 're', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'con', 'br'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 're', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 're', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'con', 'br'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'con', 'av'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'do'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'con', 'av'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'do'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 'br', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 'br', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'rep', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'br', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'br', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'rep', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 're', 'br'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'con', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 're', 'br'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 11),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'con', 'br'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'br', 'av'), 11),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 11),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'rep', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'br', 'av'), 11),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 11),	Action={('st_t', 7): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'rep', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 're', 'br'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'con', 'br'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 're', 'br'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 12),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'con', 'br'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'con', 'br'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'con', 'br'), 9),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'rep', 'av'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'do'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'av'), 9),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'do'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 10),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 'con', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 're', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 're', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'con', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 'con', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 're', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 're', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'con', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'ex', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'con', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'con', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'con', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 're', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 're', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 15),	Action={('con_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'con', 'av'), 11),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'con', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 're', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 're', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'con', 'av'), 12),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'ex', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'con', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'con', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'con', 'av'), 11),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 're', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 're', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'con', 'av'), 11),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'ex', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'con', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'con', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'con', 'av'), 11),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 're', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 're', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'con', 'av'), 11),	Action={('che_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'ex', 'av'), 9),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'con', 'do'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'con', 'br'), 10),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'rep', 'av'), 12),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'br', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'br', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'rep', 'av'), 12),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'rep', 'do'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'rep', 'br'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'rep', 'av'), 12),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'av'), 12),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'rep', 'do'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'rep', 'br'), 10),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'br', 'br'), 15),	Action={('ch_st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'br', 'br'), 15),	Action={('ch_st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 'rep', 'br'), 11),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'br', 'br'), 15),	Action={('ch_st_t', 7): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'br'), 15),	Action={('ch_st_t', 7): 1.0}
# ...
# State=(('re', 're', 're', 'br', 'do', 'do', 'rep', 'av'), 15),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'br', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'br', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'rep', 'av'), 15),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'br', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'br', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'rep', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'rep', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'rep', 'av'), 15),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'av'), 15),	Action={('rep_el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'rep', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'rep', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'rep', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'rep', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'rep', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'rep', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'ex', 'br'), 11),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'br'), 11),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'ex', 'br'), 11),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'br'), 11),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'rep', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'rep', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'rep', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'rep', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'rep', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'rep', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'ex', 'br'), 12),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'br'), 12),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'ex', 'br'), 12),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'br'), 12),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 're', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 'br', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 'ex', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 'ex', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'br', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'ex', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 'ex', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 're', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 'br', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 'ex', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 'ex', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'br', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'ex', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 'ex', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 're', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'br', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'ex', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 'ex', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'av'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'con', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'con', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'br', 'av'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'ex', 'do'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 'ex', 'br'), 13),	Action={('pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 're', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'br', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'ex', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 'ex', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'br', 'av'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'ex', 'do'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 'ex', 'br'), 14),	Action={('run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 're', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'br', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'ex', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'ex', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 're', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'br', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'ex', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'ex', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'do'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'br'), 13),	Action={('ch_pai', 5): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 're', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'br', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'ex', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'ex', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 're', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'ex', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'ex', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'do'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'br'), 14),	Action={('ch_run', 4): 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'br'), 15),	Action={('el_t', 6): 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'rep', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'do', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'do', 'br', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'do', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'br', 'br', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'do', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'do', 'br', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'do', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 're', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'br', 'av'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'do'), 16),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'br', 'br', 'ex', 'br'), 16),	Action={'undefined': 1.0}
# State=-1,	Action={'undefined': 1.0}

# %% [markdown]
# ## Automa debug

# %%
target = setup.target_service_automata()
render_target(target)

# %%
mdp = composition_mdp(target, *all_services, gamma=0.9)
render_composition_mdp(mdp)

# %%
opn = DPAnalytic(mdp, 1e-4)
opt_policy = opn.get_optimal_policy_vi()
opt_policy.policy_data.pop(0, None)
print_policy_data(opt_policy)
# Out:
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's0', 'ret_i'),	Action={0: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's1', 'ret_r'),	Action={1: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's2', 'ret_s'),	Action={2: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's3', 'con_ass'),	Action={3: 1.0}
# State=(('re', 're', 're', 'con', 'av', 'av', 're', 'av'), 's4', 'che_ass'),	Action={3: 1.0}
# State=(('re', 're', 're', 'ex', 'av', 'av', 're', 'av'), 's5', 'ass'),	Action={3: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 's5', 'ass'),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's6', 'run'),	Action={4: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 's6', 'run'),	Action={4: 1.0}
# State=(('re', 're', 're', 're', 'do', 'av', 're', 'av'), 's7', 'ch_run'),	Action={4: 1.0}
# State=(('re', 're', 're', 're', 'br', 'av', 're', 'av'), 's7', 'ch_run'),	Action={4: 1.0}
# State=(('re', 're', 're', 'br', 'do', 'av', 're', 'av'), 's7', 'ch_run'),	Action={4: 1.0}
# State=(('re', 're', 're', 'br', 'br', 'av', 're', 'av'), 's7', 'ch_run'),	Action={4: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's8', 'pai'),	Action={5: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 's8', 'pai'),	Action={5: 1.0}
# State=(('re', 're', 're', 're', 'av', 'do', 're', 'av'), 's9', 'ch_pai'),	Action={5: 1.0}
# State=(('re', 're', 're', 're', 'av', 'br', 're', 'av'), 's9', 'ch_pai'),	Action={5: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'do', 're', 'av'), 's9', 'ch_pai'),	Action={5: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'br', 're', 'av'), 's9', 'ch_pai'),	Action={5: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's10', 'con_el_t'),	Action={6: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 's10', 'con_el_t'),	Action={6: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'con', 'av'), 's11', 'che_el_t'),	Action={6: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'con', 'av'), 's11', 'che_el_t'),	Action={6: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'ex', 'av'), 's12', 'el_t'),	Action={6: 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 's12', 'el_t'),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'ex', 'av'), 's12', 'el_t'),	Action={6: 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 's12', 'el_t'),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 're', 'av'), 's13', 'no_op'),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 're', 'av', 'av', 'br', 'av'), 's13', 'no_op'),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 're', 'av'), 's13', 'no_op'),	Action={'undefined': 1.0}
# State=(('re', 're', 're', 'br', 'av', 'av', 'br', 'av'), 's13', 'no_op'),	Action={'undefined': 1.0}
